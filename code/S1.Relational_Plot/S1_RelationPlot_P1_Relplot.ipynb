# %% [markdown]
# <a href="https://colab.research.google.com/github/bdfd/00Awesome_Seaborn_Visualization_Guide/blob/main/code/S1.Relational_Plot/S1_RelationPlot_P1_Relplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting Enviorment

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
sns.set(rc={'figure.figsize':(18,18)})
# plt.rcParams.update(params)
# sns.set_theme(style="darkgrid")

# %matplotlib inline

# %%
# Version
print(mpl.__version__)  #> 3.2.2
print(sns.__version__)  #> 0.11.2
# Out:
# 3.2.2
# 0.11.2

# %% [markdown]
# # Section 1 Relational Plot Part 1 Relation Graph
#   * short cut as relplot -> show relationshop between two variables with semantic mappings
#   * use kind to determine which type plot is using either **scatter(default)** or **line**
#   * common use parameter are **hue**, **size**, and **style**, use for control visual semantics and identify different subset

# %% [markdown]
# ## Load Dataset

# %%
# Load Dataset use sns default dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# scatter plot
plt.figure(figsize=(15,16))
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
# Load Dataset use method pandas
# https://github.com/mwaskom/seaborn-data (seaborn default)
path1 = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
tip = pd.read_csv(path1)
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# scatter plot
sns.relplot(data=tip, x="total_bill", y="tip")

# %% [markdown]
# ## Add More Parameter

# %% [markdown]
# ### **Parament: hue**
#
# Grouping variable produce elements with different colors
# hue act as group clause function, and use column name in hue parameter

# %%
# parmeter: hue
sns.relplot(data=tip, x="total_bill", y="tip", hue="day")

# %%
# parmeter: hue
sns.relplot(data=tip, x="total_bill", y="tip", hue="time")

# %%
# parmeter: hue
sns.relplot(data=tip, x="total_bill", y="tip", hue="size")

# %%
# parmeter: hue & palette
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips);

# %% [markdown]
# ### **Parament col, row, colwrap**
#
# Similar function to hue, used for created figure with multiple subplots arranged across the columns and rows of the grid.<br />
# **row_order, col_order**: order to organize the rows and/or columns of the grid in, otherwise the orders are inferred from the data objects.

# %%
# parmeter: hue & col
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time")

# %%
# parmeter: hue, col, col_order, row & row_order
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", col="time", col_order=['Dinner','Lunch'], row="sex", row_order=['Female','Male'])

# %%
# parmeter: hue & col
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day")

# %%
# parmeter: hue, col & col_wrap
sns.relplot(data=tips, x="total_bill", y="tip", hue="time", col="day", col_wrap=3)

# %% [markdown]
# ### **Parameter size, style, palette, sizes**
# Multiple Semantic Variable together can show multi-dimensional relationships
# <br/>
# **size**: grouping variable that will produce elements with different sizes.<br/>
# **style**: grouping variable that will produce elements with different styles.<br/>
# **sizes**: specifying the size range for parameter size<br/>
# **palette**: choose for color

# %%
# parmeter: size & sizes
sns.relplot(data=tips, x="total_bill", y="tip", size="size", sizes=(15, 200));

# %%
# parmeter: hue & styles
sns.relplot(
    x="total_bill", y="tip", hue="smoker", style="smoker",
    data=tips
)

# %%
# parmeter: hue, col, size, style, palette, sizes
sns.relplot(
    data=tips, x="total_bill", y="tip", col="time",
    hue="time", size="size", style="sex",
    palette=["b", "r"], sizes=(0, 50)
)

# %%
# parmeter: hue, col, size, style, palette & sizes
sns.relplot(
    data=tips, x="total_bill", y="tip", col="time",
    hue="time", size="size", style="sex",
    palette=["b", "r"], sizes=(10, 100)
)

# %% [markdown]
# ### **Parameter kind**(Only Use for Choose Line Graph)

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# ### Parameter
